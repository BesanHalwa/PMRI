# %%
import tensorflow as tf
import numpy as np
import yaml
import logging
import os
from pathlib import Path
from datetime import datetime
from model import Generator  # Assuming this is a custom U-Net model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(message)s',
    handlers=[
        logging.FileHandler('training.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class SegmentationTrainer:
    """A class to handle training of a U-Net model for multi-class segmentation."""

    def __init__(self, config_path: str):
        """
        Initialize the trainer with configuration from a YAML file.

        Args:
            config_path (str): Path to the YAML configuration file.
        """
        if not os.path.exists(config_path):
            logger.error(f"Configuration file not found at {config_path}")
            raise FileNotFoundError(f"Configuration file not found at {config_path}")
        self.config = self._load_config(config_path)
        self._validate_config()
        self.data_path = Path(self.config['data']['path'])
        self.model = None
        self.train_dataset = None
        self.val_dataset = None
        self.setup_environment()

    def _load_config(self, config_path: str) -> dict:
        """Load and parse the YAML configuration file."""
        try:
            with open(config_path, 'r') as file:
                config = yaml.safe_load(file)
            logger.info(f"Loaded configuration from {config_path}")
            return config
        except Exception as e:
            logger.error(f"Failed to load config file {config_path}: {str(e)}")
            raise

    def _validate_config(self):
        """Validate the configuration parameters."""
        required_keys = [
            'data.path', 'data.buffer_size', 'data.batch_size',
            'model.img_width', 'model.img_height', 'model.input_channels', 'model.output_channels',
            'training.epochs', 'training.batch_size', 'training.weights_path',
            'training.checkpoint_dir', 'training.alpha'
        ]
        for key in required_keys:
            if not self._get_nested_config(key):
                logger.error(f"Missing or invalid configuration key: {key}")
                raise ValueError(f"Configuration key {key} is missing or invalid")

    def _get_nested_config(self, key: str):
        """Access nested dictionary keys."""
        current = self.config
        for part in key.split('.'):
            current = current.get(part)
            if current is None:
                return None
        return current

    def setup_environment(self):
        """Set up the TensorFlow environment."""
        os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            logger.info(f"Using GPU: {gpus}")
            try:
                for gpu in gpus:
                    tf.config.experimental.set_memory_growth(gpu, True)
            except RuntimeError as e:
                logger.warning(f"GPU memory growth setup failed: {str(e)}")
        else:
            logger.info("No GPU found, using CPU.")

    def load_data(self):
        """Load and preprocess training and validation datasets."""
        try:
            # Load data
            train_data_x = np.load(self.data_path / 'train_images.npy')
            train_data_y = np.load(self.data_path / 'train_masks_hot_encoded.npy')
            val_data_x = np.load(self.data_path / 'val_images.npy')
            val_data_y = np.load(self.data_path / 'val_masks_hot_encoded.npy')

            # Reshape input data to add channel dimension if missing
            if len(train_data_x.shape) == 3:
                train_data_x = train_data_x[..., np.newaxis]  # Add channel dimension: (None, 256, 256) -> (None, 256, 256, 1)
                logger.info("Added channel dimension to train_data_x")
            if len(val_data_x.shape) == 3:
                val_data_x = val_data_x[..., np.newaxis]  # Add channel dimension: (None, 256, 256) -> (None, 256, 256, 1)
                logger.info("Added channel dimension to val_data_x")

            # Validate data shapes
            expected_shape_x = (None, self.config['model']['img_height'], self.config['model']['img_width'], self.config['model']['input_channels'])
            expected_shape_y = (None, self.config['model']['img_height'], self.config['model']['img_width'], self.config['model']['output_channels'])
            self._validate_data_shapes(train_data_x, train_data_y, expected_shape_x, expected_shape_y, 'training')
            self._validate_data_shapes(val_data_x, val_data_y, expected_shape_x, expected_shape_y, 'validation')

            # Create TensorFlow datasets
            with tf.device('/cpu:0'):
                train_data_x = tf.data.Dataset.from_tensor_slices(train_data_x)
                train_data_y = tf.data.Dataset.from_tensor_slices(train_data_y)
                val_data_x = tf.data.Dataset.from_tensor_slices(val_data_x)
                val_data_y = tf.data.Dataset.from_tensor_slices(val_data_y)

                self.train_dataset = tf.data.Dataset.zip((train_data_x, train_data_y))
                self.val_dataset = tf.data.Dataset.zip((val_data_x, val_data_y))

                # Shuffle and batch
                self.train_dataset = (self.train_dataset
                                      .shuffle(self.config['data']['buffer_size'])
                                      .batch(self.config['data']['batch_size'])
                                      .prefetch(tf.data.AUTOTUNE))
                self.val_dataset = (self.val_dataset
                                    .batch(self.config['data']['batch_size'])
                                    .prefetch(tf.data.AUTOTUNE))

            logger.info("Datasets loaded and preprocessed successfully.")
        except Exception as e:
            logger.error(f"Failed to load or preprocess data: {str(e)}")
            raise

    def _validate_data_shapes(self, data_x, data_y, expected_shape_x, expected_shape_y, dataset_name: str):
        """Validate the shapes of input data."""
        if data_x.shape[1:] != expected_shape_x[1:]:
            logger.error(f"Invalid {dataset_name} input shape: got {data_x.shape}, expected {expected_shape_x}")
            raise ValueError(f"Invalid {dataset_name} input shape")
        if data_y.shape[1:] != expected_shape_y[1:]:
            logger.error(f"Invalid {dataset_name} label shape: got {data_y.shape}, expected {expected_shape_y}")
            raise ValueError(f"Invalid {dataset_name} label shape")

    def dice_coefficient(self, y_true, y_pred):
        """Compute Dice coefficient for model evaluation."""
        smooth = 1e-6
        intersection = tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
        union = tf.reduce_sum(y_true, axis=(1, 2, 3)) + tf.reduce_sum(y_pred, axis=(1, 2, 3))
        dice = (2.0 * intersection + smooth) / (union + smooth)
        return tf.reduce_mean(dice)

    def dice_loss_channel_wise(self, y_true, y_pred, smooth=1e-6):
        """Compute channel-wise Dice loss for multi-class segmentation."""
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_f = tf.reshape(y_true, (-1, y_true.shape[-1]))
        y_pred_f = tf.reshape(y_pred, (-1, y_pred.shape[-1]))
        intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
        union = tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0)
        dice = (2. * intersection + smooth) / (union + smooth)
        dice_loss_per_channel = 1 - dice
        return tf.reduce_mean(dice_loss_per_channel)

    def pixel_wise_binary_crossentropy_loss(self, y_true, y_pred):
        """Compute pixel-wise binary cross-entropy loss."""
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        bce_loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)
        return bce_loss(y_true, y_pred)

    def combined_loss(self, y_true, y_pred):
        """Combined loss function: BCE + Dice."""
        alpha = self.config['training']['alpha']
        bce_loss = self.pixel_wise_binary_crossentropy_loss(y_true, y_pred)
        dice_loss = self.dice_loss_channel_wise(y_true, y_pred)
        return alpha * bce_loss + (1 - alpha) * dice_loss

    def setup_model(self):
        """Initialize and compile the U-Net model."""
        try:
            self.model = Generator()
            weights_path = Path(self.config['training']['weights_path'])
            if weights_path.exists():
                self.model.load_weights(weights_path)
                logger.info(f"Loaded weights from {weights_path}")
            else:
                logger.warning(f"Weights file {weights_path} not found, starting with random initialization.")

            self.model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=self.config['training']['learning_rate']),
                loss=self.combined_loss,
                metrics=[self.dice_coefficient]
            )
            logger.info("Model compiled successfully.")
        except Exception as e:
            logger.error(f"Failed to set up model: {str(e)}")
            raise

    def setup_callbacks(self):
        """Set up training callbacks."""
        checkpoint_dir = Path(self.config['training']['checkpoint_dir'])
        checkpoint_dir.mkdir(parents=True, exist_ok=True)
        
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        checkpoint_path = checkpoint_dir / f'checkpoint_epoch_{{epoch:02d}}_{timestamp}.h5'

        callbacks = [
            ModelCheckpoint(
                filepath=checkpoint_path,
                save_weights_only=True,
                save_best_only=False,
                verbose=1
            ),
            EarlyStopping(
                monitor='val_loss',
                patience=self.config['training']['early_stopping_patience'],
                restore_best_weights=True,
                verbose=1
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-6,
                verbose=1
            )
        ]
        return callbacks

    def train(self):
        """Train the model."""
        try:
            self.load_data()
            self.setup_model()
            callbacks = self.setup_callbacks()

            logger.info("Starting model training...")
            history = self.model.fit(
                self.train_dataset,
                epochs=self.config['training']['epochs'],
                validation_data=self.val_dataset,
                batch_size=self.config['training']['batch_size'],
                callbacks=callbacks
            )
            logger.info("Training completed successfully.")
            return history
        except Exception as e:
            logger.error(f"Training failed: {str(e)}")
            raise

def main():
    """Main function to run the training pipeline."""
    config_path = 'config.yaml'  # Update this to the correct path if needed
    trainer = SegmentationTrainer(config_path)
    history = trainer.train()
    return history

if __name__ == '__main__':
    main()
# Out:
# 2025-05-29 11:06:40,134 [INFO] Loaded configuration from config.yaml
# 2025-05-29 11:06:40,135 [INFO] Using GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# 2025-05-29 11:06:40,311 [INFO] Added channel dimension to train_data_x
# 2025-05-29 11:06:40,311 [INFO] Added channel dimension to val_data_x
# 2025-05-29 11:06:40.445266: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.445480: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.445657: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.445822: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.445983: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.446147: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.453819: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.454017: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.454202: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.454380: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.454619: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2025-05-29 11:06:40.454754: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.454915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22272 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9
# 2025-05-29 11:06:40.455265: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 1
# 2025-05-29 11:06:40.455356: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-29 11:06:40.455508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21872 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# 2025-05-29 11:06:41,771 [INFO] Datasets loaded and preprocessed successfully.
# 2025-05-29 11:06:42,426 [INFO] Loaded weights from training_checkpoints/enhanced_unet_Generator_model_weights_ckpt47.h5
# 2025-05-29 11:06:42,437 [INFO] Model compiled successfully.
# 2025-05-29 11:06:42,438 [INFO] Starting model training...
# Epoch 1/500
# 2025-05-29 11:06:44.861220: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/sequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-05-29 11:06:45.176724: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2025-05-29 11:06:45.239149: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-05-29 11:06:45.775324: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-05-29 11:06:51.017056: I external/local_xla/xla/service/service.cc:168] XLA service 0x708b8956f940 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-05-29 11:06:51.017085: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-05-29 11:06:51.017090: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-05-29 11:06:51.020479: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748488011.088263  459583 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 37/37 [==============================] - ETA: 0s - loss: 0.7089 - dice_coefficient: 20.2600
# Epoch 1: saving model to training_checkpoints/checkpoint_epoch_01_20250529_110642.h5
# 37/37 [==============================] - 46s 704ms/step - loss: 0.7089 - dice_coefficient: 20.2600 - val_loss: 2.4187 - val_dice_coefficient: 0.2436 - lr: 0.0010
# Epoch 2/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5711 - dice_coefficient: 8.4086
# Epoch 2: saving model to training_checkpoints/checkpoint_epoch_02_20250529_110642.h5
# 37/37 [==============================] - 9s 238ms/step - loss: 0.5711 - dice_coefficient: 8.4086 - val_loss: 1.6175 - val_dice_coefficient: -1.6656 - lr: 0.0010
# Epoch 3/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5241 - dice_coefficient: 5.7915
# Epoch 3: saving model to training_checkpoints/checkpoint_epoch_03_20250529_110642.h5
# 37/37 [==============================] - 9s 239ms/step - loss: 0.5241 - dice_coefficient: 5.7915 - val_loss: 0.9677 - val_dice_coefficient: -1.0849 - lr: 0.0010
# Epoch 4/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5047 - dice_coefficient: 4.2720
# Epoch 4: saving model to training_checkpoints/checkpoint_epoch_04_20250529_110642.h5
# 37/37 [==============================] - 9s 239ms/step - loss: 0.5047 - dice_coefficient: 4.2720 - val_loss: 0.7176 - val_dice_coefficient: -0.5835 - lr: 0.0010
# Epoch 5/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4971 - dice_coefficient: -2.5072
# Epoch 5: saving model to training_checkpoints/checkpoint_epoch_05_20250529_110642.h5
# 37/37 [==============================] - 9s 236ms/step - loss: 0.4971 - dice_coefficient: -2.5072 - val_loss: 0.7950 - val_dice_coefficient: -0.8402 - lr: 0.0010
# Epoch 6/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4880 - dice_coefficient: -2.8563
# Epoch 6: saving model to training_checkpoints/checkpoint_epoch_06_20250529_110642.h5
# 37/37 [==============================] - 9s 238ms/step - loss: 0.4880 - dice_coefficient: -2.8563 - val_loss: 0.7164 - val_dice_coefficient: -3.1744 - lr: 0.0010
# Epoch 7/500
# Epoch 15: saving model to training_checkpoints/checkpoint_epoch_15_20250529_110642.h5
# 37/37 [==============================] - 9s 236ms/step - loss: 0.6868 - dice_coefficient: 2.2804 - val_loss: 0.7197 - val_dice_coefficient: 1.5965 - lr: 5.0000e-04
# Epoch 16/500
# 37/37 [==============================] - ETA: 0s - loss: 0.6877 - dice_coefficient: 2.0592
# Epoch 16: saving model to training_checkpoints/checkpoint_epoch_16_20250529_110642.h5
# 37/37 [==============================] - 9s 234ms/step - loss: 0.6877 - dice_coefficient: 2.0592 - val_loss: 0.6681 - val_dice_coefficient: 1.9523 - lr: 5.0000e-04
# Epoch 17/500
# 37/37 [==============================] - ETA: 0s - loss: 0.6570 - dice_coefficient: -1.3600
# Epoch 17: saving model to training_checkpoints/checkpoint_epoch_17_20250529_110642.h5
# 37/37 [==============================] - 9s 239ms/step - loss: 0.6570 - dice_coefficient: -1.3600 - val_loss: 0.6471 - val_dice_coefficient: 2.2669 - lr: 5.0000e-04
# Epoch 18/500
# 37/37 [==============================] - ETA: 0s - loss: 0.6381 - dice_coefficient: 3.1937
# Epoch 18: saving model to training_checkpoints/checkpoint_epoch_18_20250529_110642.h5
# 37/37 [==============================] - 9s 240ms/step - loss: 0.6381 - dice_coefficient: 3.1937 - val_loss: 0.6264 - val_dice_coefficient: 2.3971 - lr: 5.0000e-04
# Epoch 19/500
# 37/37 [==============================] - ETA: 0s - loss: 0.6251 - dice_coefficient: 2.7848
# Epoch 19: saving model to training_checkpoints/checkpoint_epoch_19_20250529_110642.h5
# 37/37 [==============================] - 9s 238ms/step - loss: 0.6251 - dice_coefficient: 2.7848 - val_loss: 0.6183 - val_dice_coefficient: 2.4689 - lr: 5.0000e-04
# Epoch 20/500
# 37/37 [==============================] - ETA: 0s - loss: 0.6124 - dice_coefficient: 3.7575
# Epoch 20: saving model to training_checkpoints/checkpoint_epoch_20_20250529_110642.h5
# 37/37 [==============================] - 9s 239ms/step - loss: 0.6124 - dice_coefficient: 3.7575 - val_loss: 0.5974 - val_dice_coefficient: 2.8072 - lr: 5.0000e-04
# Epoch 21/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5961 - dice_coefficient: 3.7129
# Epoch 21: saving model to training_checkpoints/checkpoint_epoch_21_20250529_110642.h5
# 37/37 [==============================] - 9s 236ms/step - loss: 0.5961 - dice_coefficient: 3.7129 - val_loss: 0.5833 - val_dice_coefficient: 3.0887 - lr: 5.0000e-04
# Epoch 22/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5707 - dice_coefficient: 2.7593
# Epoch 22: saving model to training_checkpoints/checkpoint_epoch_22_20250529_110642.h5
# 37/37 [==============================] - 9s 238ms/step - loss: 0.5707 - dice_coefficient: 2.7593 - val_loss: 0.5393 - val_dice_coefficient: 3.5649 - lr: 5.0000e-04
# Epoch 23/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5420 - dice_coefficient: -20.8642
# Epoch 23: saving model to training_checkpoints/checkpoint_epoch_23_20250529_110642.h5
# 37/37 [==============================] - 9s 239ms/step - loss: 0.5420 - dice_coefficient: -20.8642 - val_loss: 0.5362 - val_dice_coefficient: -3288.2305 - lr: 5.0000e-04
# Epoch 24/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5315 - dice_coefficient: -9.8653
# Epoch 24: saving model to training_checkpoints/checkpoint_epoch_24_20250529_110642.h5
# 37/37 [==============================] - 9s 236ms/step - loss: 0.5315 - dice_coefficient: -9.8653 - val_loss: 0.5198 - val_dice_coefficient: -8.4835 - lr: 5.0000e-04
# Epoch 25/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5183 - dice_coefficient: -7.9105
# Epoch 25: saving model to training_checkpoints/checkpoint_epoch_25_20250529_110642.h5
# 37/37 [==============================] - 9s 238ms/step - loss: 0.5183 - dice_coefficient: -7.9105 - val_loss: 0.5060 - val_dice_coefficient: -8.4155 - lr: 5.0000e-04
# Epoch 26/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5196 - dice_coefficient: -3.8555
# Epoch 26: saving model to training_checkpoints/checkpoint_epoch_26_20250529_110642.h5
# 37/37 [==============================] - 9s 235ms/step - loss: 0.5196 - dice_coefficient: -3.8555 - val_loss: 0.5742 - val_dice_coefficient: -1.4515 - lr: 5.0000e-04
# Epoch 27/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5306 - dice_coefficient: -1.8084
# Epoch 27: saving model to training_checkpoints/checkpoint_epoch_27_20250529_110642.h5
# 37/37 [==============================] - 9s 235ms/step - loss: 0.5306 - dice_coefficient: -1.8084 - val_loss: 0.5375 - val_dice_coefficient: -1.8527 - lr: 5.0000e-04
# Epoch 28/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5155 - dice_coefficient: -1.7565
# Epoch 28: saving model to training_checkpoints/checkpoint_epoch_28_20250529_110642.h5
# 37/37 [==============================] - 9s 236ms/step - loss: 0.5155 - dice_coefficient: -1.7565 - val_loss: 0.5167 - val_dice_coefficient: -1.9781 - lr: 5.0000e-04
# Epoch 29/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5087 - dice_coefficient: -1.8167
# Epoch 29: saving model to training_checkpoints/checkpoint_epoch_29_20250529_110642.h5
# 37/37 [==============================] - 9s 238ms/step - loss: 0.5087 - dice_coefficient: -1.8167 - val_loss: 0.5010 - val_dice_coefficient: -2.1555 - lr: 5.0000e-04
# Epoch 30/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5073 - dice_coefficient: -1.9004
# Epoch 30: saving model to training_checkpoints/checkpoint_epoch_30_20250529_110642.h5
# 37/37 [==============================] - 9s 237ms/step - loss: 0.5073 - dice_coefficient: -1.9004 - val_loss: 0.4898 - val_dice_coefficient: -2.1262 - lr: 5.0000e-04
# Epoch 31/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4955 - dice_coefficient: -1.8445
# Epoch 31: saving model to training_checkpoints/checkpoint_epoch_31_20250529_110642.h5
# 37/37 [==============================] - ETA: 0s - loss: 0.4822 - dice_coefficient: -3.0604
# Epoch 56: saving model to training_checkpoints/checkpoint_epoch_56_20250529_110642.h5
# 37/37 [==============================] - 9s 233ms/step - loss: 0.4822 - dice_coefficient: -3.0604 - val_loss: 0.4704 - val_dice_coefficient: -3.3176 - lr: 2.5000e-04
# Epoch 57/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4811 - dice_coefficient: -3.1445
# Epoch 57: saving model to training_checkpoints/checkpoint_epoch_57_20250529_110642.h5
# 37/37 [==============================] - 9s 235ms/step - loss: 0.4811 - dice_coefficient: -3.1445 - val_loss: 0.4701 - val_dice_coefficient: -3.3720 - lr: 2.5000e-04
# Epoch 58/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4809 - dice_coefficient: -3.2760
# Epoch 58: saving model to training_checkpoints/checkpoint_epoch_58_20250529_110642.h5
# 37/37 [==============================] - 9s 237ms/step - loss: 0.4809 - dice_coefficient: -3.2760 - val_loss: 0.4694 - val_dice_coefficient: -3.5433 - lr: 2.5000e-04
# Epoch 59/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4810 - dice_coefficient: -3.4852
# Epoch 59: saving model to training_checkpoints/checkpoint_epoch_59_20250529_110642.h5
# 37/37 [==============================] - 9s 235ms/step - loss: 0.4810 - dice_coefficient: -3.4852 - val_loss: 0.4711 - val_dice_coefficient: -3.8285 - lr: 2.5000e-04
# Epoch 60/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4811 - dice_coefficient: -3.7191
# Epoch 60: saving model to training_checkpoints/checkpoint_epoch_60_20250529_110642.h5
# 37/37 [==============================] - 9s 237ms/step - loss: 0.4811 - dice_coefficient: -3.7191 - val_loss: 0.4692 - val_dice_coefficient: -4.2356 - lr: 2.5000e-04
# Epoch 61/500
# 37/37 [==============================] - ETA: 0s - loss: 0.4781 - dice_coefficient: -4.1994
# Epoch 61: saving model to training_checkpoints/checkpoint_epoch_61_20250529_110642.h5
# 37/37 [==============================] - 9s 237ms/step - loss: 0.4781 - dice_coefficient: -4.1994 - val_loss: 0.4650 - val_dice_coefficient: -5.1036 - lr: 2.5000e-04
# Epoch 62/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5108 - dice_coefficient: 9.5799
# Epoch 62: saving model to training_checkpoints/checkpoint_epoch_62_20250529_110642.h5
# 37/37 [==============================] - 9s 234ms/step - loss: 0.5108 - dice_coefficient: 9.5799 - val_loss: 0.5663 - val_dice_coefficient: 35.3648 - lr: 2.5000e-04
# Epoch 63/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5474 - dice_coefficient: 14.3922
# Epoch 63: saving model to training_checkpoints/checkpoint_epoch_63_20250529_110642.h5
# 37/37 [==============================] - 9s 234ms/step - loss: 0.5474 - dice_coefficient: 14.3922 - val_loss: 0.5323 - val_dice_coefficient: 19.2243 - lr: 2.5000e-04
# Epoch 64/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5202 - dice_coefficient: -169.4933
# Epoch 72: saving model to training_checkpoints/checkpoint_epoch_72_20250529_110642.h5
# 37/37 [==============================] - 9s 235ms/step - loss: 0.5245 - dice_coefficient: 33.8173 - val_loss: 0.5128 - val_dice_coefficient: 24.9485 - lr: 1.2500e-04
# Epoch 73/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5200 - dice_coefficient: -14.8959
# Epoch 73: saving model to training_checkpoints/checkpoint_epoch_73_20250529_110642.h5
# 37/37 [==============================] - 9s 234ms/step - loss: 0.5200 - dice_coefficient: -14.8959 - val_loss: 0.5063 - val_dice_coefficient: 50.2190 - lr: 1.2500e-04
# Epoch 74/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5181 - dice_coefficient: 12.3713
# Epoch 74: saving model to training_checkpoints/checkpoint_epoch_74_20250529_110642.h5
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 37/37 [==============================] - 9s 234ms/step - loss: 0.5181 - dice_coefficient: 12.3713 - val_loss: 0.5025 - val_dice_coefficient: 7.2405 - lr: 1.2500e-04
# Epoch 75/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5133 - dice_coefficient: 27.1513
# Epoch 75: saving model to training_checkpoints/checkpoint_epoch_75_20250529_110642.h5
# 37/37 [==============================] - 9s 237ms/step - loss: 0.5133 - dice_coefficient: 27.1513 - val_loss: 0.5005 - val_dice_coefficient: 141.1525 - lr: 6.2500e-05
# Epoch 76/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5114 - dice_coefficient: -392.4550
# Epoch 76: saving model to training_checkpoints/checkpoint_epoch_76_20250529_110642.h5
# 37/37 [==============================] - 9s 234ms/step - loss: 0.5114 - dice_coefficient: -392.4550 - val_loss: 0.4989 - val_dice_coefficient: 59.1000 - lr: 6.2500e-05
# Epoch 77/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5098 - dice_coefficient: 14.3218
# Epoch 77: saving model to training_checkpoints/checkpoint_epoch_77_20250529_110642.h5
# 37/37 [==============================] - 9s 234ms/step - loss: 0.5098 - dice_coefficient: 14.3218 - val_loss: 0.4971 - val_dice_coefficient: 80.2517 - lr: 6.2500e-05
# Epoch 78/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5083 - dice_coefficient: -82.4460
# Epoch 78: saving model to training_checkpoints/checkpoint_epoch_78_20250529_110642.h5
# 37/37 [==============================] - 9s 233ms/step - loss: 0.5083 - dice_coefficient: -82.4460 - val_loss: 0.4959 - val_dice_coefficient: -13.8840 - lr: 6.2500e-05
# Epoch 79/500
# 37/37 [==============================] - ETA: 0s - loss: 0.5070 - dice_coefficient: -19.4508
# Epoch 79: saving model to training_checkpoints/checkpoint_epoch_79_20250529_110642.h5
# Restoring model weights from the end of the best epoch: 69.
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 37/37 [==============================] - 9s 238ms/step - loss: 0.5070 - dice_coefficient: -19.4508 - val_loss: 0.4947 - val_dice_coefficient: -424.7094 - lr: 6.2500e-05
# Epoch 79: early stopping
# 2025-05-29 11:18:49,866 [INFO] Training completed successfully.

# %%
import numpy as np
data_path = '/home/besanhalwa/Eshan/project1_PMRI/Data/npy_tech_pmri_no_aug_leftRightSplit/'
test_x = np.load(data_path + 'test_images.npy')
test_y = np.load(data_path + 'test_masks_hot_encoded.npy')
print("Test images shape:", test_x.shape)  # Should be (num_samples, 256, 256) or (num_samples, 256, 256, 1)
print("Test masks shape:", test_y.shape)   # Should be (num_samples, 256, 256, 6)
# Out:
# Test images shape: (312, 256, 256)
# Test masks shape: (312, 256, 256, 6)

# %%
test_results = trainer.evaluate_test_data(num_samples_to_visualize=5)  # Visualize 5 samples

# %%
import tensorflow as tf
import numpy as np
import yaml
import logging
import os
from pathlib import Path
import matplotlib.pyplot as plt
from model import Generator  # Assuming this is a custom U-Net model

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(message)s',
    handlers=[
        logging.FileHandler('evaluation.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class SegmentationEvaluator:
    """A class to handle evaluation and visualization of a U-Net model on test data."""

    def __init__(self, config_path: str):
        """
        Initialize the evaluator with configuration from a YAML file.

        Args:
            config_path (str): Path to the YAML configuration file.
        """
        if not os.path.exists(config_path):
            logger.error(f"Configuration file not found at {config_path}")
            raise FileNotFoundError(f"Configuration file not found at {config_path}")
        self.config = self._load_config(config_path)
        self._validate_config()
        self.data_path = Path(self.config['data']['path'])
        self.model = None
        self.test_dataset = None
        self.setup_environment()

    def _load_config(self, config_path: str) -> dict:
        """Load and parse the YAML configuration file."""
        try:
            with open(config_path, 'r') as file:
                config = yaml.safe_load(file)
            logger.info(f"Loaded configuration from {config_path}")
            return config
        except Exception as e:
            logger.error(f"Failed to load config file {config_path}: {str(e)}")
            raise

    def _validate_config(self):
        """Validate the configuration parameters."""
        required_keys = [
            'data.path', 'data.batch_size',
            'model.img_width', 'model.img_height', 'model.input_channels', 'model.output_channels',
            'training.weights_path'
        ]
        for key in required_keys:
            if not self._get_nested_config(key):
                logger.error(f"Missing or invalid configuration key: {key}")
                raise ValueError(f"Configuration key {key} is missing or invalid")

    def _get_nested_config(self, key: str):
        """Access nested dictionary keys."""
        current = self.config
        for part in key.split('.'):
            current = current.get(part)
            if current is None:
                return None
        return current

    def setup_environment(self):
        """Set up the TensorFlow environment."""
        os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            logger.info(f"Using GPU: {gpus}")
            try:
                for gpu in gpus:
                    tf.config.experimental.set_memory_growth(gpu, True)
            except RuntimeError as e:
                logger.warning(f"GPU memory growth setup failed: {str(e)}")
        else:
            logger.info("No GPU found, using CPU.")

    def load_test_data(self):
        """Load and preprocess test dataset."""
        try:
            # Load test data
            test_data_x = np.load(self.data_path / 'test_images.npy')
            test_data_y = np.load(self.data_path / 'test_masks_hot_encoded.npy')

            # Reshape input data to add channel dimension if missing
            if len(test_data_x.shape) == 3:
                test_data_x = test_data_x[..., np.newaxis]  # Add channel dimension: (None, 256, 256) -> (None, 256, 256, 1)
                logger.info("Added channel dimension to test_data_x")

            # Validate test data shapes
            expected_shape_x = (None, self.config['model']['img_height'], self.config['model']['img_width'], self.config['model']['input_channels'])
            expected_shape_y = (None, self.config['model']['img_height'], self.config['model']['img_width'], self.config['model']['output_channels'])
            self._validate_data_shapes(test_data_x, test_data_y, expected_shape_x, expected_shape_y, 'test')

            # Create TensorFlow dataset
            with tf.device('/cpu:0'):
                test_data_x = tf.data.Dataset.from_tensor_slices(test_data_x)
                test_data_y = tf.data.Dataset.from_tensor_slices(test_data_y)
                self.test_dataset = tf.data.Dataset.zip((test_data_x, test_data_y))
                self.test_dataset = self.test_dataset.batch(self.config['data']['batch_size']).prefetch(tf.data.AUTOTUNE)

            logger.info("Test dataset loaded and preprocessed successfully.")
        except Exception as e:
            logger.error(f"Failed to load or preprocess test data: {str(e)}")
            raise

    def _validate_data_shapes(self, data_x, data_y, expected_shape_x, expected_shape_y, dataset_name: str):
        """Validate the shapes of input data."""
        if data_x.shape[1:] != expected_shape_x[1:]:
            logger.error(f"Invalid {dataset_name} input shape: got {data_x.shape}, expected {expected_shape_x}")
            raise ValueError(f"Invalid {dataset_name} input shape")
        if data_y.shape[1:] != expected_shape_y[1:]:
            logger.error(f"Invalid {dataset_name} label shape: got {data_y.shape}, expected {expected_shape_y}")
            raise ValueError(f"Invalid {dataset_name} label shape")

    def dice_coefficient(self, y_true, y_pred):
        """Compute Dice coefficient for model evaluation."""
        smooth = 1e-6
        intersection = tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
        union = tf.reduce_sum(y_true, axis=(1, 2, 3)) + tf.reduce_sum(y_pred, axis=(1, 2, 3))
        dice = (2.0 * intersection + smooth) / (union + smooth)
        return tf.reduce_mean(dice)

    def setup_model(self):
        """Initialize and compile the U-Net model."""
        try:
            self.model = Generator()
            weights_path = Path(self.config['training']['weights_path'])
            if weights_path.exists():
                self.model.load_weights(weights_path)
                logger.info(f"Loaded weights from {weights_path}")
            else:
                logger.error(f"Weights file {weights_path} not found")
                raise FileNotFoundError(f"Weights file {weights_path} not found")

            self.model.compile(
                optimizer=tf.keras.optimizers.Adam(),
                loss=self.combined_loss,
                metrics=[self.dice_coefficient]
            )
            logger.info("Model compiled successfully.")
        except Exception as e:
            logger.error(f"Failed to set up model: {str(e)}")
            raise

    def combined_loss(self, y_true, y_pred):
        """Combined loss function: BCE + Dice."""
        alpha = self.config['training']['alpha']
        bce_loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)(y_true, y_pred)
        dice_loss = self.dice_loss_channel_wise(y_true, y_pred)
        return alpha * bce_loss + (1 - alpha) * dice_loss

    def dice_loss_channel_wise(self, y_true, y_pred, smooth=1e-6):
        """Compute channel-wise Dice loss for multi-class segmentation."""
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_f = tf.reshape(y_true, (-1, y_true.shape[-1]))
        y_pred_f = tf.reshape(y_pred, (-1, y_pred.shape[-1]))
        intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
        union = tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0)
        dice = (2. * intersection + smooth) / (union + smooth)
        dice_loss_per_channel = 1 - dice
        return tf.reduce_mean(dice_loss_per_channel)

    def evaluate_and_visualize(self, num_samples_to_visualize=3):
        """Evaluate the model on test data and display results in a Jupyter Notebook."""
        try:
            self.load_test_data()
            self.setup_model()

            # Evaluate model on test data
            logger.info("Evaluating model on test data...")
            test_results = self.model.evaluate(self.test_dataset, return_dict=True)
            logger.info(f"Test results: {test_results}")

            # Generate predictions for visualization
            test_images, test_masks = next(iter(self.test_dataset.take(1)))  # Get one batch
            predictions = self.model.predict(test_images)

            # Convert predictions to class indices for visualization
            pred_masks = np.argmax(predictions, axis=-1)  # Shape: (batch_size, 256, 256)
            true_masks = np.argmax(test_masks, axis=-1)   # Shape: (batch_size, 256, 256)

            # Visualize results
            plt.figure(figsize=(15, 5 * num_samples_to_visualize))
            for i in range(min(num_samples_to_visualize, test_images.shape[0])):
                # Input image (grayscale)
                plt.subplot(num_samples_to_visualize, 3, i * 3 + 1)
                plt.imshow(test_images[i, :, :, 0], cmap='gray')
                plt.title(f'Input Image {i+1}')
                plt.axis('off')

                # Ground truth mask
                plt.subplot(num_samples_to_visualize, 3, i * 3 + 2)
                plt.imshow(true_masks[i], cmap='jet', vmin=0, vmax=self.config['model']['output_channels']-1)
                plt.title(f'Ground Truth Mask {i+1}')
                plt.axis('off')

                # Predicted mask
                plt.subplot(num_samples_to_visualize, 3, i * 3 + 3)
                plt.imshow(pred_masks[i], cmap='jet', vmin=0, vmax=self.config['model']['output_channels']-1)
                plt.title(f'Predicted Mask {i+1}')
                plt.axis('off')

            plt.tight_layout()
            plt.show()

            return test_results
        except Exception as e:
            logger.error(f"Failed to evaluate test data: {str(e)}")
            raise

def main():
    """Main function to run the evaluation pipeline."""
    config_path = 'config.yaml'  # Update this to the correct path if needed
    evaluator = SegmentationEvaluator(config_path)
    test_results = evaluator.evaluate_and_visualize(num_samples_to_visualize=3)
    return test_results

if __name__ == '__main__':
    # Enable inline plotting for Jupyter Notebook
    # %matplotlib inline
    test_results = main()
# Out:
# 2025-05-28 17:17:29,655 [INFO] Loaded configuration from config.yaml
# 2025-05-28 17:17:29,655 [INFO] Using GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# 2025-05-28 17:17:29,679 [INFO] Added channel dimension to test_data_x
# 2025-05-28 17:17:29,795 [INFO] Test dataset loaded and preprocessed successfully.
# 2025-05-28 17:17:30,351 [INFO] Loaded weights from training_checkpoints/checkpoint_epoch_59.h5
# 2025-05-28 17:17:30,356 [INFO] Model compiled successfully.
# 2025-05-28 17:17:30,356 [INFO] Evaluating model on test data...
# 5/5 [==============================] - 1s 66ms/step - loss: 0.5366 - dice_coefficient: -0.5412
# 2025-05-28 17:17:31,182 [INFO] Test results: {'loss': 0.5365535616874695, 'dice_coefficient': -0.5411785840988159}
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x72b251b020e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2025-05-28 17:17:31,450 [WARNING] 6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x72b251b020e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 27ms/step

# %%
 predictions = model.predict(test_images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 predictions = model.predict(test_images)
#
# NameError: name 'model' is not defined
